# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import os
import seaborn as sns

# %%
#After improrting all the libraries that are important for cleaning the data that is to be processed for an analysis.

# %%
print(os.listdir())#getting all the files in the directry
# Out:
# ['.ipynb_checkpoints', 'ad comp.ipynb', 'agri.zip', 'archive', 'archive.zip', 'data.csv', 'facebook.zip', 'PlantVillage', 'supermarket_sales - Sheet1.csv', 'super_market.zip', 'TH_DA_2_StringMatching_Graph_Geo.pptx', 'tomato', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb']

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df.isnull().sum()
# Out:
# ad_id                    0
# reporting_start          0
# reporting_end            0
# campaign_id              0
# fb_campaign_id           0
# age                      0
# gender                   0
# interest1                0
# interest2                0
# interest3                0
# impressions              0
# clicks                   0
# spent                    0
# total_conversion       382
# approved_conversion    382
# dtype: int64

# %%
#there are still some missing values that are sometimes missed by the isnull() statement

# %%
missing_value=["N/A","na","NaN",np.nan]
df = pd.read_csv("data.csv",na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# ad_id                    0
# reporting_start          0
# reporting_end            0
# campaign_id              0
# fb_campaign_id           0
# age                      0
# gender                   0
# interest1                0
# interest2                0
# interest3                0
# impressions              0
# clicks                   0
# spent                    0
# total_conversion       382
# approved_conversion    382
# dtype: int64

# %%
#as we can see that all the null variables inputs are detected and hence we will now cross check with the help of seaborn library

# %%
sns.heatmap(df.isnull(),yticklabels=False, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Now we can remove all the missing value fron the dataset.

# %%
df
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df.dropna(how="all")
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
#as of now we have dropped all the values that are of no use as they will alter the result in a very vivid ways and decrease the confidence level

# %%
# now we that we have all te rows that show null value we will fill it up with 
#the abrivated values

# %%
df.fillna(0)#very unconventional method and hence not good
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df.fillna(method='ffill')#forward fill
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df.fillna(method='bfill')#does not work for the following case
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df.interpolate()
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17/08/2017    17/08/2017         916         103916  30-34
# 1      708749      17/08/2017    17/08/2017         916         103917  30-34
# 2      708771      17/08/2017    17/08/2017         916         103920  30-34
# 3      708815      30/08/2017    30/08/2017         916         103928  30-34
# 4      708818      17/08/2017    17/08/2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F    109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F    110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F    111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F    113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F    114
#
# ...

# %%
df.to_csv('output.csv',index=False)

# %% [markdown]
# # now the data is cleaned and ready to be used in for data visualization.
